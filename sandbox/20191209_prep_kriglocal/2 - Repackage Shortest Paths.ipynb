# %% [markdown]
# # Repackage Shortest Paths Zipfiles
#
# This notebook repackages the zip files in `shortest_path.zip` as a single pandas HDF5 to be read in by `Prepare Kriging.ipynb`.

# %%
# Check for duplicate ref IDs.
import glob
import re
import numpy as np
import pandas as pd

files = glob.glob(('/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/'
                   'PRTCS/negative/shortest_path_csv/*.csv'))
# Sort by file number without leading zeros.
extract_fileno = re.compile(r'\d+')
files = sorted(files, key=lambda x: int(extract_fileno.findall(x.split("/")[-1])[0]))

for file in files:
    df = pd.read_csv(file)
    if df['ref_id'].unique().shape[0] != 1:
        raise ValueError('Found a file with more than one ref id!')

# %% [markdown]
# So every file has a unique ref ID.  This is great.

# %%
seen_values = []
bad_files = []

for file in files:
    df = pd.read_csv(file)
    ref_id = df['ref_id'].unique()[0]
    if ref_id in seen_values:
        bad_files.append(file)
    else:
        seen_values.append(ref_id)

# %%
len(bad_files)
# Out:
# 7028

# %%
bad_files
# Out:
# ['/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13243.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13244.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13245.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13246.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13247.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13248.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13249.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13250.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13251.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13252.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13253.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13254.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13255.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13256.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13257.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13258.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13259.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13260.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13261.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13262.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13263.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13264.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13265.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13266.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13267.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13268.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13269.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13270.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13271.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13272.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13273.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13274.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13275.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13276.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13277.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13278.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13279.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13280.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13281.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13282.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13283.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13284.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13285.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13286.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13287.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13288.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13289.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13290.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13291.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13292.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13293.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13294.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13295.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13296.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13297.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13298.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13299.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13300.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13301.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13302.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13303.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13304.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13305.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13306.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13307.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13308.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13309.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13310.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13311.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13312.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13313.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13314.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13315.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13316.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13317.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13318.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13319.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13320.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13321.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13322.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13323.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13324.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13325.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13326.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13327.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13328.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13329.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13330.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13331.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13332.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13333.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13334.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13335.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13336.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13337.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13338.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13339.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13340.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13341.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13342.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13343.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13344.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13345.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13346.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13347.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13348.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13349.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13350.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13351.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13352.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13353.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13354.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13355.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13356.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13357.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13358.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13359.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13360.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13361.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13362.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13363.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13364.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13365.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13366.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13367.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13368.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13369.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13370.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13371.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13372.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13373.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13374.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13375.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13376.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13377.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13378.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13379.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13380.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13381.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13382.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13383.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13384.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13385.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13386.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13387.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13388.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13389.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13390.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13391.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13392.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13393.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13394.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13395.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13396.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13397.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13398.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13399.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13400.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13401.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13402.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13403.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13404.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13405.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13406.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13407.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13408.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13409.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13410.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13411.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13412.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13413.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13414.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13415.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13416.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13417.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13418.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13419.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13420.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13421.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13422.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13423.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13424.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13425.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13426.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13427.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13428.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13429.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13430.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13431.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13432.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13433.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13434.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13435.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13436.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13437.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13438.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13439.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13440.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13441.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13442.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13443.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13444.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13445.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13446.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13447.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13448.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13449.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13450.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13451.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13452.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13453.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13454.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13455.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13456.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13457.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13458.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13459.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13460.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13461.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13462.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13463.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13464.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13465.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13466.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13467.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13468.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13469.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13470.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13471.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13472.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13473.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13474.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13475.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13476.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13477.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13478.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13479.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13480.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13481.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13482.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13483.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13484.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13485.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13486.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13487.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13488.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13489.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13490.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13491.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13492.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13493.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13494.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13495.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13496.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13497.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13498.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13499.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13500.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13501.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13502.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13503.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13504.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13505.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13506.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13507.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13508.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13509.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13510.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13511.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13512.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13513.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13514.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13515.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13516.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13517.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13518.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13519.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13520.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13521.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13522.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13523.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13524.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13525.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13526.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13527.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13528.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13529.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13530.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13531.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13532.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13533.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13534.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13535.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13536.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13537.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13538.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13539.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13540.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13541.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13542.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13543.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13544.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13545.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13546.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13547.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13548.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13549.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13550.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13551.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13552.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13553.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13554.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13555.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13556.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13557.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13558.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13559.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13560.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13561.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13562.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13563.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13564.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13565.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13566.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13567.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13568.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13569.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13570.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13571.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13572.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13573.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13574.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13575.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13576.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13577.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13578.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13579.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13580.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13581.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13582.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13583.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13584.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13585.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13586.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13587.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13588.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13589.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13590.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13591.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13592.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13593.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13594.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13595.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13596.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13597.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13598.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13599.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13600.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13601.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13602.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13603.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13604.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13605.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13606.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13607.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13608.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13609.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13610.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13611.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13612.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13613.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13614.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13615.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13616.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13617.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13618.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13619.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13620.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13621.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13622.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13623.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13624.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13625.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13626.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13627.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13628.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13629.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13630.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13631.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13632.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13633.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13634.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13635.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13636.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13637.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13638.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13639.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13640.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13641.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13642.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13643.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13644.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13645.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13646.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13647.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13648.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13649.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13650.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13651.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13652.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13653.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13654.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13655.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13656.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13657.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13658.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13659.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13660.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13661.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13662.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13663.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13664.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13665.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13666.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13667.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13668.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13669.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13670.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13671.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13672.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13673.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13674.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13675.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13676.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13677.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13678.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13679.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13680.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13681.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13682.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13683.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13684.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13685.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13686.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13687.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13688.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13689.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_13767.dbf.csv',
# ...
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14174.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14175.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14176.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14177.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14178.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14179.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14180.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14181.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14182.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14183.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14184.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14185.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14186.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14187.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14188.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14189.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14190.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14191.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14192.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14194.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14195.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14196.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14197.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14198.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14199.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14200.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14201.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14202.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14203.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14204.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14205.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14206.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14207.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14208.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14209.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14210.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14211.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14212.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14213.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14291.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14292.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14293.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14294.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14295.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14296.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14297.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14298.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14299.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14300.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14301.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14302.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14303.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14304.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14305.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14306.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14307.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14308.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14309.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14310.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14311.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14312.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14313.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14314.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14315.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14316.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14317.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14318.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14319.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14320.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14321.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14322.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14323.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14324.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14325.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14326.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14327.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14328.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14329.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14330.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14331.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14332.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14333.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14334.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14335.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14336.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14337.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14338.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14339.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14340.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14341.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14342.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14343.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14344.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14345.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14346.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14347.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14348.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14349.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14350.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14351.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14352.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14353.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14354.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14355.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14356.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14357.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14358.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14359.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14360.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14361.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14362.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14363.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14364.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14365.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14366.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14367.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14368.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14369.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14370.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14371.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14372.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14373.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14374.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14375.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14376.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14377.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14378.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14379.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14380.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14381.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14382.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14383.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14384.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14385.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14386.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14387.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14388.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14389.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14390.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14391.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14392.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14393.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14394.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14395.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14396.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14397.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14398.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14399.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_14400.dbf.csv',
#  ...]

# %% [markdown]
# So `ref_id` is not unique...
#
# Is there any logic to how `ref_id` works?

# %%
ref_id = []
file_id = []
centreline_id = []

dupctr_file_id = []
dupctr_centrelines = []

extract_fileno = re.compile(r'\d+')

for file in files:
    df = pd.read_csv(file)
    ref_id.append(df['ref_id'].unique()[0])
    file_id.append(int(extract_fileno.findall(file.split("/")[-1])[0]))
    unique_ctrline_ids = df.loc[df['network_distance'] < 1e-10, 'centreline_id'].unique()
    if len(unique_ctrline_ids) != 1:
        dupctr_file_id.append(file)
        dupctr_centrelines.append(unique_ctrline_ids)
    centreline_id.append(unique_ctrline_ids[0])

# %%
dupctr_file_id
# Out:
# ['/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_246.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_279.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_480.dbf.csv',
#  '/mnt/c/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/routh_481.dbf.csv']

# %%
dupctr_centrelines
# Out:
# [array([1143129, 8128848]),
#  array([1143129, 8128848]),
#  array([103008, 103141]),
#  array([103008, 103141])]

# %% [markdown]
# Simple solution - assign `1143129` to `routh_246.dbf.csv`, `8128848` to `routh_279.dbf.csv`, etc.

# %%
rc_df = pd.DataFrame({
    'ref_id': ref_id,
    'file_id': file_id,
    'centreline_id': centreline_id
})

# %%
rc_counts = rc_df.groupby('ref_id')['ref_id'].count()
rc_counts[rc_counts > 1].head()
# Out:
# ref_id
# 1    3
# 2    3
# 3    3
# 4    3
# 5    3
# Name: ref_id, dtype: int64

# %%
rc_df.groupby('ref_id').get_group(2)
# Out:
#        ref_id  file_id  centreline_id
# 1           2        2       14188125
# 12833       2    13244         912255
# 18432       2    20638       20061414

# %%
np.all(rc_df.loc[:12831, 'ref_id'] == rc_df.loc[:12831, 'file_id'] )
# Out:
# True

# %%
rc_df.loc[12832:16000, 'ref_id']
# Out:
# 12832       1
# 12833       2
# 12834       3
# 12835       4
# 12836       5
# 12837       6
# 12838       7
# 12839       8
# 12840       9
# 12841      10
# 12842      11
# 12843      12
# 12844      13
# 12845      14
# 12846      15
# 12847      16
# 12848      17
# 12849      18
# 12850      19
# 12851      20
# 12852      21
# 12853      22
# 12854      23
# 12855      24
# 12856      25
# 12857      26
# 12858      27
# 12859      28
# 12860      29
# 12861      30
#          ...
# 15971    3679
# 15972    3680
# 15973    3681
# 15974    3682
# 15975    3683
# 15976    3684
# 15977    3685
# 15978    3686
# 15979    3687
# 15980    3688
# 15981    3689
# 15982    3690
# 15983    3691
# 15984    3692
# 15985    3693
# 15986    3694
# 15987    3695
# 15988    3696
# 15989    3697
# 15990    3698
# 15991    3699
# 15992    3700
# 15993    3701
# 15994    3702
# 15995    3703
# 15996    3704
# 15997    3705
# 15998    3706
# 15999    3707
# 16000    3708
# Name: ref_id, Length: 3169, dtype: int64

# %%
rc_df.loc[12832:16000, 'ref_id'].shape
# Out:
# (3169,)

# %% [markdown]
# So once the `ref_id`s cycle back to 1 they don't increment in steps of 1, and by 19000 they start looping back to 100, 200, etc.  We should just use the file name as the reference number.

# %% [markdown]
# Tried a `dask` thing:

# %%
# We probably don't need Dask for data this size, but it helps us read a bunch of CSVs in without appending to
# the same dataframe 20k times.
# import dask.dataframe as dd
# ddf = dd.read_csv('/mnt/bad_filesc/Users/czhu5/Documents/VolumeModel/TEPS-dev/PRTCS/negative/shortest_path_csv/*.csv')
# # Drop duplicates
# df = ddf.drop_duplicates().compute()
# # This is also way slower than just reading all 20k files into RAM.

# %% [markdown]
# But this doesn't work because we have too many preprocessing steps prior.

# %%
extract_fileno = re.compile(r'\d+')
duplicated_centreline_lookup = pd.Series(
    [1143129, 8128848, 103008, 103141], index=dupctr_file_id
)

def preproc_file(filename):
    cdf = pd.read_csv(filename)

    # sanity check that there's only one ref id.
    if cdf['ref_id'].unique().shape[0] != 1:
        raise ValueError('Found a file with more than one ref id!')

    # Extract reference number from file, and use that as the reference ID 
    extract_fileno = re.compile(r'\d+')
    file_ref_num = int(extract_fileno.findall(filename.split("/")[-1])[0])
    if cdf['ref_id'].unique()[0] != file_ref_num:
        cdf['ref_id'] = file_ref_num

    # Find and record the origin centreline ID (for a given reference number it's the)
    # one with network distance of zero.  The exception is for files with duplicate
    # origins - these are manually fixed using `duplicated_centreline_lookup`.
    if filename in duplicated_centreline_lookup.index:
        wanted_id = duplicated_centreline_lookup[filename]
        cdf['origin_centreline_id'] = wanted_id
        cdf.loc[(cdf['network_distance'] < 1e-10) &
                (cdf['centreline_id'] != wanted_id), 'network_distance'] = 0.001
    else:
        unique_ctrline_ids = cdf.loc[cdf['network_distance'] < 1e-10, 'centreline_id'].unique()
        if len(unique_ctrline_ids) != 1:
            raise ValueError('somehow file {0} has multiple zero-distance centrelines.'.format(filename))
        cdf['origin_centreline_id'] = unique_ctrline_ids[0]

    # Ensure unique from-to IDs (ignore street information).
    cdf.drop_duplicates(subset=('ref_id', 'centreline_id',
                                'speed_limit', 'network_distance'), inplace=True)
    
    # Sanity check of prior processing steps.
    cdf_zero_dist = cdf.loc[cdf['network_distance'] < 1e-10, :]
    assert cdf_zero_dist.shape[0] == 1
    assert cdf_zero_dist['centreline_id'].values == cdf_zero_dist['origin_centreline_id'].values
    return cdf

df = pd.concat([preproc_file(file) for file in files], ignore_index=True)

# %%
# Ensure street name formatting is consistent.
df['street_name'] = df['street_name'].str.upper()
# Point fix for Elizabeth street turning into Dr. Emily Stowe Way.
df.loc[df['centreline_id'].isin([14647000, 14023284, 14646999, 14647005]), 'street_name'] = 'DR. EMILY STOWE WAY'

# %%
# Create a map between reference ID and centreline ID.
ref_ctrline_table = df.loc[df['network_distance'] == 0, ['ref_id', 'centreline_id']]

# %%
# Check that there are no ref_ids that are used by two different centreline_ids.
unique_map_test = ref_ctrline_table.groupby('ref_id')['centreline_id'].count()
assert not np.any(unique_map_test != 1)

# %%
# Check that there are no centreline_ids used by two different ref_ids
unique_map_test = ref_ctrline_table.groupby('centreline_id')['ref_id'].count()
assert not np.any(unique_map_test != 1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-2464b2a5c234> in <module>
#       1 # Check that there are no centreline_ids used by two different ref_ids
#       2 unique_map_test = ref_ctrline_table.groupby('centreline_id')['ref_id'].count()
# ----> 3 assert not np.any(unique_map_test != 1)
#
# AssertionError:

# %% [markdown]
# Oh.

# %%
unique_map_test[unique_map_test > 1].head(10)
# Out:
# centreline_id
# 1003    2
# 1821    2
# 1899    2
# 7228    2
# 7640    2
# 7777    2
# 7968    2
# 8090    2
# 8174    2
# 8310    2
# Name: ref_id, dtype: int64

# %%
ref_ctrline_table.loc[ref_ctrline_table['centreline_id'] == 8310, :]
# Out:
#         ref_id  centreline_id
# 34568      127           8310
# 867608    2997           8310

# %%
ref_ctrline_table.loc[ref_ctrline_table['centreline_id'] == 30017253, :]
# Out:
#          ref_id  centreline_id
# 4269568   14330       30017253
# 5145530   21203       30017253

# %%
df.loc[df['ref_id'] == 127, :].head()
# Out:
#        ref_id  centreline_id  street_name  speed_limit  network_distance  \
# 34557     127        7074349    WESTON RD           50           1.93365
# 34558     127           7640    WESTON RD           50           1.69070
# 34559     127           8879    ROGERS RD           50           1.82065
# 34560     127        8155608    ROGERS RD           50           1.95372
# 34561     127        9085034  GULLIVER RD           50           2.82439
#
#        origin_centreline_id
# 34557                  8310
# 34558                  8310
# 34559                  8310
# 34560                  8310
# 34561                  8310

# %%
df.loc[df['ref_id'] == 2997, :].head()
# Out:
#         ref_id  centreline_id  street_name  speed_limit  network_distance  \
# 867597    2997        7074349    WESTON RD           50           1.93365
# 867598    2997           7640    WESTON RD           50           1.69070
# 867599    2997           8879    ROGERS RD           50           1.82065
# 867600    2997        8155608    ROGERS RD           50           1.95372
# 867601    2997        9085034  GULLIVER RD           50           2.82439
#
#         origin_centreline_id
# 867597                  8310
# 867598                  8310
# 867599                  8310
# 867600                  8310
# 867601                  8310

# %% [markdown]
# Okay, we need to drop duplicates.

# %%
df.drop_duplicates(subset=['centreline_id', 'street_name', 'speed_limit',
                           'network_distance', 'origin_centreline_id'], inplace=True)

# %%
ref_ctrline_table = df.loc[df['network_distance'] == 0, ['ref_id', 'centreline_id']]

# %%
# Check again that there are no centreline_ids used by two different ref_ids
unique_map_test = ref_ctrline_table.groupby('centreline_id')['ref_id'].count()
assert not np.any(unique_map_test != 1)

# %% [markdown]
# Yay!  However this does not end the saga, since what we really need to do is also make sure every given *origin* centreline ID refers only to one reference ID.  In some cases where the two `ref_id`s represent two separate queries for the same centreline, there will be some duplicate rows (including the zero network distance rows) and some that aren't, but still need to have their `ref_id` changed so that there's a 1-to-1 mapping between `ref_id` and `origin_centreline_id`.

# %%
# Find all origin centreline IDs mapped to more than one reference ID.
duplicate_ref_ids = (df.groupby(['origin_centreline_id', 'ref_id'])['centreline_id']
                     .count().reset_index().drop(columns='centreline_id')
                     .groupby('origin_centreline_id')['ref_id'].count())

# %%
duplicate_ref_ids[duplicate_ref_ids > 1].index.values
# Out:
# array([    1003,   102817,   102823, ..., 30029636, 30033762, 30033763])

# %%
# Create a one-to-one mapping between ref_id and origin_centreline_id (which, when network distance is zero, is
# the same as `centreline_id`).
ref_ctrline_map = pd.Series(ref_ctrline_table['ref_id'].values,
                            index=ref_ctrline_table['centreline_id'].values)

# %%
ref_ctrline_map[102817]
# Out:
# 470

# %%
from tqdm.notebook import tqdm

for oci in tqdm(duplicate_ref_ids[duplicate_ref_ids > 1].index.values):
    df.loc[df['origin_centreline_id'] == oci, 'ref_id'] = ref_ctrline_map[oci]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2530.0), HTML(value='')))

# %%
# Double check that we've removed all duplicate reference IDs.
oci_refid_map = df.groupby('origin_centreline_id')['ref_id'].agg(['max', 'min'])
assert np.array_equal(oci_refid_map['max'], oci_refid_map['min'])
oci_refid_map['mapping'] = ref_ctrline_map[oci_refid_map.index]
assert np.array_equal(oci_refid_map['max'], oci_refid_map['mapping'])

# %% [markdown]
# YAY!

# %%
df.columns
# Out:
# Index(['ref_id', 'centreline_id', 'street_name', 'speed_limit',
#        'network_distance', 'origin_centreline_id'],
#       dtype='object')

# %%
df.rename(columns={
    'ref_id': 'origin_ref_id',
    'centreline_id': 'dest_centreline_id'}, inplace=True)

# %%
oci_ref_table = df.loc[df['network_distance'] == 0, ['origin_ref_id', 'origin_centreline_id']].reset_index(drop=True)
oci_ref_table.columns = ['dest_ref_id', 'dest_centreline_id']

# %%
df = pd.merge(df, oci_ref_table, how='left', left_on='dest_centreline_id', right_on='dest_centreline_id')

# %% [markdown]
# There are still some NaNs in `dest_ref_id`, but this means that `df` is not a full distance matrix (and it may not matter for constructing variograms).

# %%
df.reset_index(drop=True, inplace=True)

# This is basically resmat.txt without the land use data.
with pd.HDFStore('/home/czhu/Data/btp_sandbox_prep_kriglocaldata/resmat.hdf5', 'w') as store:
    store['resmat'] = df
